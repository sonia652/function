# %% [markdown]
# ASSIGNMENT : FUNCTIONS
#
# THEORY QUESTIONS
#
# QUESTION 1. What is the difference between a function and a method in Python?
#
#    .  Function: A block of code that performs a task, defined using def, and can be called independently.
#
# Method: A function that is associated with an object (e.g., belongs to a class).
#
# Example
# python
# Copy
# Edit
# # Function
# def add(a, b):
#     return a + b
#
# print(add(2, 3))  # calling a function
#
# # Method
# text = "hello"
# print(text.upper())  # here, upper() is a method of string object
#
#
#
# QUESTION 2.  Explain the concept of function arguments and parameters in Python.
#
#    . Parameters: Variables listed in the function definition.
#
# Arguments: Actual values passed to the function when calling it.
#
# Example
# python
# Copy
# Edit
# def greet(name):  # 'name' is a parameter
#     print("Hello,", name)
#
# greet("Sonia")    # "Sonia" is an argument
#
#
#
# QUESTION 3. What are the different ways to define and call a function in Python?
#
#    . Ways to define a function:
#
# Using def keyword (normal function)
#
# Using lambda keyword (anonymous function)
#
# ✅ Ways to call a function:
#
# By writing its name followed by parentheses and passing arguments if needed.
#
# Example
# python
# Copy
# Edit
# # Using def
# def square(x):
#     return x * x
#
# print(square(4))
#
# # Using lambda
# double = lambda x: x * 2
# print(double(5))
#
#
# QUESTION 4. What is the purpose of the `return` statement in a Python function?
#
#  . Purpose of return:
# To send back a value from a function to where it was called and end the function execution.
#
# Example
# python
# Copy
# Edit
# def add(a, b):
#     return a + b
#
# result = add(3, 4)
# print(result)  # Output: 7
#
#
# QUESTION 5 . What are iterators in Python and how do they differ from iterables?
#
#   . Iterable: An object that can be looped over (e.g., list, string).
#
#   Iterator: An object with a next() method that remembers its position and gives next value on each call.
#
# Example
# python
# Copy
# Edit
# nums = [1, 2, 3]   # iterable
#
# it = iter(nums)   # creating iterator from iterable
#
# print(next(it))   # Output: 1
# print(next(it))   # Output: 2
#
#
# QUESTION 6.  Explain the concept of generators in Python and how they are defined.
#
#  . ✅ Generators:
# Functions that yield items one by one instead of returning all at once, saving memory.
#
# ✅ Defined using:
#
# def with yield keyword.
#
# Example
# python
# Copy
# Edit
# def count_up_to(n):
#     for i in range(1, n+1):
#         yield i
#
# for num in count_up_to(3):
#     print(num)
# ✔ Output:
# 1
# 2
# 3
#
#
# QUESTION 7. What are the advantages of using generators over regular functions?

# %% [markdown]
#  Advantages of generators:
#
# Memory efficient (don’t store entire data in memory)
#
# Faster for large data (generate items on-the-fly)
#
# Example
# python
# Copy
# Edit
# def gen_numbers():
#     for i in range(1000000):
#         yield i  # generator
#
# # vs
#
# def list_numbers():
#     return [i for i in range(1000000)]  # regular function creating large list
#
#
#
# QUESTION 8 . What is a lambda function in Python and when is it typically used?
#
#
#  . ✅ Lambda function:
# An anonymous, short function defined using lambda keyword.
#
# ✅ Typically used:
# When a simple function is needed quickly, especially as an argument to functions like map, filter, etc.
#
# Example
# python
# Copy
# Edit
# square = lambda x: x * x
# print(square(5))  # Output: 25
#
#
#
# QUESTION 9 .  Explain the purpose and usage of the `map()` function in Python.
#  #.✅ Purpose of map():
# Applies a function to each item in an iterable and returns a map object (iterator) with results.
#
# Example
# python
# Copy
# Edit
# nums = [1, 2, 3, 4]
# squared = map(lambda x: x*x, nums)
# print(list(squared))  # Output: [1, 4, 9, 16]
#
#
# QUESTION 10 . What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#
# .  ✅ map() – Applies a function to each item in an iterable and returns the results.
# ✅ filter() – Filters items in an iterable based on a condition (function returning True/False).
# ✅ reduce() – Applies a function cumulatively to items, reducing them to a single value.
#
# Example
# python
# Copy
# Edit
# from functools import reduce
#
# nums = [1, 2, 3, 4]
#
# # map: square each number
# squared = list(map(lambda x: x*x, nums))
# print(squared)  # [1, 4, 9, 16]
#
# # filter: keep even numbers
# evens = list(filter(lambda x: x%2==0, nums))
# print(evens)  # [2, 4]
#
# # reduce: multiply all numbers together
# product = reduce(lambda x, y: x*y, nums)
# print(product)  # 24

# %% [markdown]
#   # PRACTICAL QUESTIONS
#
# QUESTION 1.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
#
# # .def sum_of_evens(numbers):
#     total = 0
#     for num in numbers:
#         if num % 2 == 0:
#             total += num
#     return total
#
# # Example usage
# nums = [1, 2, 3, 4, 5, 6]
# print(sum_of_evens(nums))  # Output: 12
#
#
# QUESTION 2 . Create a Python function that accepts a string and returns the reverse of that string.
#
# #. def reverse_string(s):
#     return s[::-1]
#
# # Example usage
# text = "hello"
# print(reverse_string(text))  # Output: "olleh"
#
#
# QUESTION 3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
#
# #. def squares_list(numbers):
#     result = []
#     for num in numbers:
#         result.append(num * num)
#     return result
#
# # Example usage
# nums = [1, 2, 3, 4]
# print(squares_list(nums))  # Output: [1, 4, 9, 16]
#
# # QUESTION 4.  Write a Python function that checks if a given number is prime or not from 1 to 200.
#
# #. def is_prime(n):
#     if n <= 1:
#         return False
#     for i in range(2, int(n**0.5)+1):
#         if n % i == 0:
#             return False
#     return True
#
# # Example usage: checking primes from 1 to 200
# for num in range(1, 201):
#     if is_prime(num):
#         print(num, "is prime")
#
#
# #QUESTION 5 . Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
#
# #. class Fibonacci:
#     def __init__(self, n):
#         self.n = n  # total number of terms
#         self.count = 0
#         self.a = 0
#         self.b = 1
#
#     def __iter__(self):
#         return self
#
#     def __next__(self):
#         if self.count < self.n:
#             if self.count == 0:
#                 self.count += 1
#                 return self.a
#             elif self.count == 1:
#                 self.count += 1
#                 return self.b
#             else:
#                 self.a, self.b = self.b, self.a + self.b
#                 self.count += 1
#                 return self.b
#         else:
#             raise StopIteration
#
# # Example usage
# fib = Fibonacci(10)
# for num in fib:
#     print(num)
#
#
#
# #QUESTION 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
#
# #. def powers_of_two(max_exp):
#     for exp in range(max_exp + 1):
#         yield 2 ** exp
#
# # Example usage
# for value in powers_of_two(5):
#     print(value)
# ✔ Output:
# 1
# 2
# 4
# 8
# 16
# 32
#
# #QUESTION 7. Implement a generator function that reads a file line by line and yields each line as a string.
#
# #. def read_file_lines(filename):
#     with open(filename, 'r') as file:
#         for line in file:
#             yield line.strip()
#
# # Example usage
# # for line in read_file_lines('example.txt'):
# #     print(line)
# ✔ Explanation:
#
# . Uses with open for safe file handling
#
# . yield returns each line as a string one by one
#
#  . .strip() removes trailing newline characters.
#
# #QUESTION 8 .Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
#
# #. # List of tuples
# items = [(1, 3), (2, 1), (4, 2)]
#
# # Sorting using lambda
# sorted_items = sorted(items, key=lambda x: x[1])
#
# print(sorted_items)  # Output: [(2, 1), (4, 2), (1, 3)]
#
#
# #QUESTION 9 . Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
#
# #. # List of temperatures in Celsius
# celsius = [0, 20, 37, 100]
#
# # Conversion using map and lambda
# fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
#
# print(fahrenheit)  # Output: [32.0, 68.0, 98.6, 212.0]
#
#
#
# #QUESTION 10 . Create a Python program that uses `filter()` to remove all the vowels from a given string.
#
# #. def remove_vowels(s):
#     vowels = 'aeiouAEIOU'
#     result = ''.join(filter(lambda x: x not in vowels, s))
#     return result
#
# # Example usage
# text = "Hello World"
# print(remove_vowels(text))  # Output: "Hll Wrld"
#
#
# # QUESTION 11.  Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#  ORDER   BOOK TITLE AND AUTHOR                   QUANTITY      PRICE PER ITEM
#  34587   learning python, mark lutz                4              40. 95
#  98762   programing python ,mark lutz              5              56. 80
#  77226   head first python , paul barry            3              32. 95
#  88112   einfuhrung in python3 , bernd klein       3              24. 99
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.
